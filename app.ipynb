# %%
import pandas as pd
import numpy as np
from flask import Flask, request, render_template
import pickle

# %%
app=Flask(__name__)
model=pickle.load(open('model.pkl','rb'))

# %%
@app.route('/')

def home():
    return render_template('index.html')

@app.route('/predict',methods=['POST'])
def predict():
    
    int_feature=[int(x) for x in request.form.values()]
    final_feature=[np.array(int_feature)]
    prediction=model.predict(final_feature)
    
    output=round(prediction[0],2)
    
    return render_template('index.html',prediction_text='Employee salary should be $ {}'.format(output))

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Jul/2020 21:06:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jul/2020 21:06:11] "GET /static/css/style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jul/2020 21:06:11] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jul/2020 21:06:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jul/2020 21:06:21] "GET /static/css/style.css HTTP/1.1" 404 -
